# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshithah4114/Laptop_Price_Prediction/blob/main/Laptop_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data=pd.read_csv('/content/drive/MyDrive/Laptop - Sheet1.csv')
data.head()
# Out:
#   Company   TypeName  Ram  Weight  TouchScreen  Ips         Ppi  \
# 0   Apple  Ultrabook    8    1.37            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34            0    0  127.677940
# 2      HP   Notebook    8    1.86            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu_brand      Os      Price
# 0  Intel Core i5    0  128     Intel     Mac  11.175755
# 1  Intel Core i5    0    0     Intel     Mac  10.776777
# 2  Intel Core i5    0  256     Intel  Others  10.329931
# 3  Intel Core i7    0  512       AMD     Mac  11.814476
# 4  Intel Core i5    0  256     Intel     Mac  11.473101

# %%
data.tail()
# Out:
#      Company            TypeName  Ram  Weight  TouchScreen  Ips         Ppi  \
# 1268    Asus            Notebook    4    2.20            0    0  100.454670
# 1269  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1270  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1271  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1272      HP            Notebook    6    2.19            0    0  100.454670
#
#                   Cpu_brand   HDD  SSD Gpu_brand       Os      Price
# 1268          Intel Core i7   500    0    Nvidia  Windows  10.555257
# 1269          Intel Core i7     0  128     Intel  Windows  10.433899
# 1270          Intel Core i7     0  512     Intel  Windows  11.288115
# 1271  Other Intel Processor     0    0     Intel  Windows   9.409283
# 1272          Intel Core i7  1000    0       AMD  Windows  10.614129

# %%
data.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         0
# TouchScreen    0
# Ips            0
# Ppi            0
# Cpu_brand      0
# HDD            0
# SSD            0
# Gpu_brand      0
# Os             0
# Price          0
# dtype: int64

# %%
data.nunique()
# Out:
# Company         19
# TypeName         6
# Ram              9
# Weight         171
# TouchScreen      2
# Ips              2
# Ppi             39
# Cpu_brand        5
# HDD              6
# SSD             13
# Gpu_brand        3
# Os               3
# Price          791
# dtype: int64

# %%
data=pd.get_dummies(data)

# %%
data
# Out:
#       Ram  Weight  TouchScreen  Ips         Ppi   HDD  SSD      Price  \
# 0       8    1.37            0    1  226.983005     0  128  11.175755
# 1       8    1.34            0    0  127.677940     0    0  10.776777
# 2       8    1.86            0    0  141.211998     0  256  10.329931
# 3      16    1.83            0    1  220.534624     0  512  11.814476
# 4       8    1.37            0    1  226.983005     0  256  11.473101
# ...   ...     ...          ...  ...         ...   ...  ...        ...
# 1268    4    2.20            0    0  100.454670   500    0  10.555257
# 1269    4    1.80            1    1  157.350512     0  128  10.433899
# 1270   16    1.30            1    1  276.053530     0  512  11.288115
# 1271    2    1.50            0    0  111.935204     0    0   9.409283
# 1272    6    2.19            0    0  100.454670  1000    0  10.614129
#
#       Company_Acer  Company_Apple  ...  Cpu_brand_Intel Core i3  \
# ...

# %%
X=data.drop('Price',axis=1)
X
# Out:
#       Ram  Weight  TouchScreen  Ips         Ppi   HDD  SSD  Company_Acer  \
# 0       8    1.37            0    1  226.983005     0  128         False
# 1       8    1.34            0    0  127.677940     0    0         False
# 2       8    1.86            0    0  141.211998     0  256         False
# 3      16    1.83            0    1  220.534624     0  512         False
# 4       8    1.37            0    1  226.983005     0  256         False
# ...   ...     ...          ...  ...         ...   ...  ...           ...
# 1268    4    2.20            0    0  100.454670   500    0         False
# 1269    4    1.80            1    1  157.350512     0  128         False
# 1270   16    1.30            1    1  276.053530     0  512         False
# 1271    2    1.50            0    0  111.935204     0    0         False
# 1272    6    2.19            0    0  100.454670  1000    0         False
#
#       Company_Apple  Company_Asus  ...  Cpu_brand_Intel Core i3  \
# ...

# %%
y=data['Price']
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1268    10.555257
# 1269    10.433899
# 1270    11.288115
# 1271     9.409283
# 1272    10.614129
# Name: Price, Length: 1273, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=32,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,roc_auc_score,mean_squared_log_error
from sklearn.model_selection import cross_val_predict
print("R2 Score: ",r2_score(y_test,y_pred))
print("Mean squared error: ",mean_squared_error(y_test,y_pred))
print("Mean absolute error: ",mean_absolute_error(y_test,y_pred))
rms = np.sqrt(mean_squared_error(y_test,y_pred))
print("Root mean square: ",rms)
# Out:
# R2 Score:  0.7809605585464592
# Mean squared error:  0.0818219357314322
# Mean absolute error:  0.21659377285253167
# Root mean square:  0.286045338594133

# %%
lr.coef_,lr.intercept_
# Out:
# (array([ 2.45778324e-02,  5.49829089e-02, -7.64198970e-02,  3.99827644e-02,
#          2.09951089e-03, -6.85031108e-06,  5.97620216e-04, -1.16219641e-01,
#          1.47515518e-01, -4.33138650e-02, -4.00604189e-01,  3.74356474e-02,
#         -1.07050797e-01,  3.77703284e-01,  6.75412773e-02, -5.09855745e-02,
#          3.18687228e-01, -1.64716402e-02,  1.30656786e-01, -4.72947108e-01,
#          1.81171890e-01,  1.51237334e-01,  1.88921460e-01,  1.65042352e-01,
#         -6.54844760e-01,  9.65247981e-02, -1.04953949e-02, -1.40606669e-02,
#         -1.58055730e-01, -2.13875151e-01,  1.89866666e-02,  3.77500276e-01,
#         -2.18613595e-01, -4.25489580e-02,  2.44806379e-01,  3.18931889e-01,
#         -3.02575715e-01, -5.58941287e-02,  1.33364382e-02,  4.25576905e-02,
#          1.47515518e-01, -1.99126067e-01,  5.16105484e-02]),
#  9.977500669237912)

# %%
# !pip install requests
# !pip install tabulate
# !pip install future
# !pip install h2o
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.8/265.8 MB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for h2o: filename=h2o-3.46.0.6-py2.py3-none-any.whl size=265859786 sha256=fa471f84db093e216acfa43a0066f7ecb8d55418ba24dc597798d9ad04ab9488
#   Stored in directory: /root/.cache/pip/wheels/0c/95/eb/b449c73f478dbc4557b80170cf7f2aa6db15862877e9a63536
# Successfully built h2o
# ...

# %%
import h2o
from h2o.automl import H2OAutoML

# %%
h2o.init(nthreads=-1,max_mem_size=12)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.25" 2024-10-15; OpenJDK Runtime Environment (build 11.0.25+9-post-Ubuntu-1ubuntu122.04); OpenJDK 64-Bit Server VM (build 11.0.25+9-post-Ubuntu-1ubuntu122.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.10/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmphzblnqtx
#   JVM stdout: /tmp/tmphzblnqtx/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmphzblnqtx/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         05 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# ...

# %%
train=h2o.H2OFrame(data)
X_intercept=list(X.columns)
y_intercept="Price"
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
auto_ml = H2OAutoML(max_models=10, seed=1)
auto_ml.train(x=X_intercept, y=y_intercept, training_frame=train)
# Out:
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# ...
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_1_20241124_154339
#
#
# Model Summary for Stacked Ensemble:
# key                                   value
# ------------------------------------  ----------------
# Stacking strategy                     cross_validation
# Number of base models (used / total)  8/10
# # GBM base models (used / total)      3/4
# # XGBoost base models (used / total)  3/3
# # DRF base models (used / total)      1/2
# # GLM base models (used / total)      1/1
# Metalearner algorithm                 GLM
# Metalearner fold assignment scheme    Random
# Metalearner nfolds                    5
# Metalearner fold_column
# Custom metalearner hyperparameters    None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.013233246854225571
# RMSE: 0.11503585029991986
# ...

# %%
# !pip install tpot
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 6.0 MB/s eta 0:00:00
# ...
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11939 sha256=0e183026c3f9c714354163c0c8c3f833119121b609cee19725de907f0a3ee2bf
#   Stored in directory: /root/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Laptop - Sheet1.csv')
data.head()
# Out:
#   Company   TypeName  Ram  Weight  TouchScreen  Ips         Ppi  \
# 0   Apple  Ultrabook    8    1.37            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34            0    0  127.677940
# 2      HP   Notebook    8    1.86            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu_brand      Os      Price
# 0  Intel Core i5    0  128     Intel     Mac  11.175755
# 1  Intel Core i5    0    0     Intel     Mac  10.776777
# 2  Intel Core i5    0  256     Intel  Others  10.329931
# 3  Intel Core i7    0  512       AMD     Mac  11.814476
# 4  Intel Core i5    0  256     Intel     Mac  11.473101

# %%
data.tail()
# Out:
#      Company            TypeName  Ram  Weight  TouchScreen  Ips         Ppi  \
# 1268    Asus            Notebook    4    2.20            0    0  100.454670
# 1269  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1270  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1271  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1272      HP            Notebook    6    2.19            0    0  100.454670
#
#                   Cpu_brand   HDD  SSD Gpu_brand       Os      Price
# 1268          Intel Core i7   500    0    Nvidia  Windows  10.555257
# 1269          Intel Core i7     0  128     Intel  Windows  10.433899
# 1270          Intel Core i7     0  512     Intel  Windows  11.288115
# 1271  Other Intel Processor     0    0     Intel  Windows   9.409283
# 1272          Intel Core i7  1000    0       AMD  Windows  10.614129

# %%
data.isnull().sum()
# Out:
# Company        0
# TypeName       0
# Ram            0
# Weight         0
# TouchScreen    0
# Ips            0
# Ppi            0
# Cpu_brand      0
# HDD            0
# SSD            0
# Gpu_brand      0
# Os             0
# Price          0
# dtype: int64

# %%
data.replace('?',np.nan,inplace=True)
data.replace('#',np.nan,inplace=True)

# %%
data=pd.get_dummies(data)

# %%
data
# Out:
#       Ram  Weight  TouchScreen  Ips         Ppi   HDD  SSD      Price  \
# 0       8    1.37            0    1  226.983005     0  128  11.175755
# 1       8    1.34            0    0  127.677940     0    0  10.776777
# 2       8    1.86            0    0  141.211998     0  256  10.329931
# 3      16    1.83            0    1  220.534624     0  512  11.814476
# 4       8    1.37            0    1  226.983005     0  256  11.473101
# ...   ...     ...          ...  ...         ...   ...  ...        ...
# 1268    4    2.20            0    0  100.454670   500    0  10.555257
# 1269    4    1.80            1    1  157.350512     0  128  10.433899
# 1270   16    1.30            1    1  276.053530     0  512  11.288115
# 1271    2    1.50            0    0  111.935204     0    0   9.409283
# 1272    6    2.19            0    0  100.454670  1000    0  10.614129
#
#       Company_Acer  Company_Apple  ...  Cpu_brand_Intel Core i3  \
# ...

# %%
X=data.drop('Price',axis=1)
X
# Out:
#       Ram  Weight  TouchScreen  Ips         Ppi   HDD  SSD  Company_Acer  \
# 0       8    1.37            0    1  226.983005     0  128         False
# 1       8    1.34            0    0  127.677940     0    0         False
# 2       8    1.86            0    0  141.211998     0  256         False
# 3      16    1.83            0    1  220.534624     0  512         False
# 4       8    1.37            0    1  226.983005     0  256         False
# ...   ...     ...          ...  ...         ...   ...  ...           ...
# 1268    4    2.20            0    0  100.454670   500    0         False
# 1269    4    1.80            1    1  157.350512     0  128         False
# 1270   16    1.30            1    1  276.053530     0  512         False
# 1271    2    1.50            0    0  111.935204     0    0         False
# 1272    6    2.19            0    0  100.454670  1000    0         False
#
#       Company_Apple  Company_Asus  ...  Cpu_brand_Intel Core i3  \
# ...

# %%
y=data['Price']
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1268    10.555257
# 1269    10.433899
# 1270    11.288115
# 1271     9.409283
# 1272    10.614129
# Name: Price, Length: 1273, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=32)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from tpot import TPOTRegressor
model = TPOTRegressor(generations=5, population_size=50, cv=5, scoring='neg_mean_squared_error', verbosity=2, random_state=1, n_jobs=-1)
model.fit(X_train, y_train)
# Out:
# Optimization Progress:   0%|          | 0/300 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: -0.04647457174945295
#
# Generation 2 - Current best internal CV score: -0.04647457174945295
#
# Generation 3 - Current best internal CV score: -0.04647457174945295
#
# Generation 4 - Current best internal CV score: -0.04556949908478681
#
# Generation 5 - Current best internal CV score: -0.04556949908478681
#
# Best pipeline: XGBRegressor(input_matrix, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=100, n_jobs=1, objective=reg:squarederror, subsample=0.8500000000000001, verbosity=0)
# TPOTRegressor(generations=5, n_jobs=-1, population_size=50, random_state=1,
#               scoring='neg_mean_squared_error', verbosity=2)

# %%
y_pred=lr.predict(X_test)
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,roc_auc_score,mean_squared_log_error
from sklearn.model_selection import cross_val_predict
print("R2 Score: ",r2_score(y_test,y_pred))
print("Mean squared error: ",mean_squared_error(y_test,y_pred))
print("Mean absolute error: ",mean_absolute_error(y_test,y_pred))
rms = np.sqrt(mean_squared_error(y_test,y_pred))
print("Root mean square: ",rms)
# Out:
# R2 Score:  0.7809605585464592
# Mean squared error:  0.0818219357314322
# Mean absolute error:  0.21659377285253167
# Root mean square:  0.286045338594133

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 65.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 9.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...

# %%
import gradio as gr

def predict(Company, TypeName, Ram, Weight, TouchScreen, Ips, Ppi, Cpu_brand, HDD, SSD, Gpu_brand, Os):
    preprocessed_data = [Company, TypeName, Ram, Weight, int(TouchScreen), int(Ips), Ppi, Cpu_brand, HDD, SSD, Gpu_brand, Os]
    preprocessed_data = np.array(preprocessed_data).reshape(1, -1)
    prediction = model.predict(preprocessed_data)
    predicted_price = round(prediction[0][0], 2)
    return [f"Predicted Laptop Price: ${predicted_price:.2f}"]

interface = gr.Interface(
    fn=predict,
    inputs=[
        gr.Dropdown(choices=["Acer", "Apple", "Asus", "Chuwi", "Dell", "Fujitsu", "Google", "HP", "Huawei", "LG", "Lenovo", "MSI", "Mediacom", "Microsoft", "Razer", "Samsung", "Toshiba", "Vero", "Xiaomi"], label="Company"),
        gr.Dropdown(choices=["2 in 1 Convertible", "Gaming", "Netbook", "Notebook", "Ultrabook", "Workstation"], label="Laptop Type"),
        gr.Textbox(label="RAM (in GB)"),
        gr.Textbox(label="Weight (in pounds)"),
        gr.Dropdown(choices=[("1", "Yes"), ("0", "No")], label="Touch Screen"),
        gr.Dropdown(choices=[("1", "Yes"), ("0", "No")], label="LCD Screen"),
        gr.Textbox(label="Pixels per inch"),
        gr.Dropdown(choices=[("AMD Processor", "AMD"), ("Intel Core i3", "Intel"), ("Intel Core i5", "Intel"), ("Intel Core i7", "Intel"), ("Other Core Processor", "Other")], label="CPU Brand"),
        gr.Textbox(label="HDD (in GB)"),
        gr.Textbox(label="SSD (in GB)"),
        gr.Dropdown(choices=[("AMD", "AMD"), ("Intel", "Intel"), ("Nvidia", "Nvidia")], label="Graphics Processing Unit Brand"),
        gr.Dropdown(choices=[("Mac", "Apple"), ("Windows", "Windows"), ("Others", "Others")], label="OS"),
    ],
    outputs=["number"],
    title="Laptop Price Prediction",
)

interface.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://3b7372b389086f39ca.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3b7372b389086f39ca.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
